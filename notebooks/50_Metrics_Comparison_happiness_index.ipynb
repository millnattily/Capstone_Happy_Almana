# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files_2_read = ["../data/Metrics_Summary_basemodel.txt",
                "../data/Metrics_Summary_model_01.txt",
                "../data/Metrics_Summary_model_02.txt",
                "../data/Metrics_Summary_model_03.txt",
                "../data/Metrics_Summary_model_04.txt",
                "../data/Metrics_Summary_model_05.txt",
                "../data/Metrics_Summary_model_06.txt",
                "../data/Metrics_Summary_model_07.txt",
                "../data/Metrics_Summary_model_08.txt",
                "../data/Metrics_Summary_model_09.txt",
                ]

# %%
df = pd.concat((pd.read_csv(f) for f in files_2_read))
df
# Out:
#                                  model_name  train_rmse  train_r2  train_mae
# 0                       basemodel_lin_reg_5       0.671     0.642      0.529  \
# 1                       basemodel_lin_reg_8       0.662     0.651      0.519
# 2                       basemodel_lin_reg_7       0.663     0.650      0.523
# 3                        basemodel_knn_1_25       0.634     0.680      0.497
# 4                        basemodel_knn_2_25       0.634     0.680      0.497
# ..                                      ...         ...       ...        ...
# 18  model_09_forest_tree_depth6_max_leaf_15       0.464     0.833      0.361
# 19  model_09_forest_tree_depth6_max_leaf_20       0.448     0.845      0.349
# 20  model_09_forest_tree_depth5_max_leaf_20       0.451     0.843      0.350
# 21                       model_09_ada_boost       0.484     0.819      0.397
# 22                       model_09_gbr_boost       0.347     0.907        NaN
#
#     train_mape  test_rmse  test_r2  test_mae  test_mape  delta_RMSE
# 0        0.104      0.676    0.638     0.530      0.104       0.005  \
# 1        0.103      0.669    0.645     0.520      0.102       0.007
# 2        0.103      0.671    0.643     0.521      0.102       0.008
# 3        0.098      0.634    0.681     0.506      0.099       0.000
# 4        0.098      0.634    0.681     0.506      0.099       0.000
# ..         ...        ...      ...       ...        ...         ...
# 18       0.073      0.512    0.802     0.387      0.079       0.048
# 19       0.070      0.501    0.811     0.379      0.077       0.053
# 20       0.071      0.504    0.809     0.381      0.077       0.053
# 21       0.078      0.528    0.791     0.410      0.082       0.044
# 22         NaN      0.453    0.845       NaN        NaN       0.106
#
#     delta_MAE  delta_R2  mean_node_num  mean_depth  num_of_trees
# 0       0.001     0.004            NaN         NaN           NaN
# 1       0.001     0.006            NaN         NaN           NaN
# 2       0.002     0.007            NaN         NaN           NaN
# 3       0.009     0.001            NaN         NaN           NaN
# 4       0.009     0.001            NaN         NaN           NaN
# ..        ...       ...            ...         ...           ...
# 18      0.026     0.031           29.0         5.0         100.0
# 19      0.030     0.034           39.0         5.0         100.0
# 20      0.031     0.034           39.0         5.0         100.0
# 21      0.013     0.028            NaN         NaN           NaN
# 22        NaN     0.062            NaN         NaN           NaN
#
# [213 rows x 15 columns]

# %%
g=sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# KNN Models

# %%
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'test_r2',
              color = 'darkorange',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'test_mae',
              color = 'green',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'train_r2',
              color = 'darkorange',
              markers= '',
              linestyles='--')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'train_mae',
              color = 'green',
              markers= '',
              linestyles='--')
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,

# %% [markdown]
# Decision Tree Models

# %% [markdown]
# g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
#               x= 'model_name',
#               y = 'test_r2',
#               color = 'darkorange',
#               markers= '',
#               linestyles='-')
# g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
#               x= 'model_name',
#               y = 'test_mae',
#               color = 'green',
#               markers= '',
#               linestyles='-')
# g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
#               x= 'model_name',
#               y = 'train_r2',
#               color = 'darkorange',
#               markers= '',
#               linestyles='--')
# g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
#               x= 'model_name',
#               y = 'train_mae',
#               color = 'green',
#               markers= '',
#               linestyles='--')
# g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# Random Forest Models

# %%
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'test_r2',
              color = 'darkorange',
              markers= 'o',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'test_mae',
              color = 'green',
              markers= 'o',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'train_r2',
              color = 'darkorange',
              markers= '*',
              linestyles='--')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'train_mae',
              color = 'green',
              markers= '*',
              linestyles='--')
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# MAPE - Mean absolute percentage error

# %% [markdown]
# What is a good mean absolute percentage error? A MAPE less than 5% is considered as an indication that the forecast is acceptably accurate. A MAPE greater than 10% but less than 25% indicates low, but acceptable accuracy and MAPE greater than 25% very low accuracy.

# %%
df[df['test_mape']==df['test_mape'].min()]
# Out:
#                                  model_name  train_rmse  train_r2  train_mae
# 21  model_07_forest_tree_depth5_max_leaf_30       0.437     0.852      0.339  \
# 22  model_07_forest_tree_depth6_max_leaf_25       0.433     0.854      0.337
# 3                         model_08_knn_1_15       0.454     0.840      0.346
#
#     train_mape  test_rmse  test_r2  test_mae  test_mape  delta_RMSE
# 21       0.069      0.484    0.822     0.364      0.074       0.047  \
# 22       0.068      0.484    0.822     0.365      0.074       0.051
# 3        0.070      0.480    0.826     0.363      0.074       0.026
#
#     delta_MAE  delta_R2  mean_node_num  mean_depth  num_of_trees
# 21      0.025     0.030           58.0         5.0         100.0
# 22      0.028     0.032           49.0         6.0         100.0
# 3       0.017     0.014            NaN         NaN           NaN

# %% [markdown]
# Welches sind die besten Modelle? (aus meiner Sicht)
#
#
# ### Random Tree: Model 7
#
# depth 5 or 6
#
# Features:
# + log_gdp_per_capita
# + social_support
# + healthy_life_expectancy_at_birth
# +
# + perception of corruption
# + positive affect
# + negative affect
#
# ! without freedom_to_make_life_choices
#
# ### KNN Model: Model 8
#
# manhattan, 15 neighbors
#
# Features:
# + log_gdp_per_capita
# + social_support
# + healthy_life_expectancy_at_birth
# +
# +
# + positive affect
# + negative affect
#
# ! without freedom_to_make_life_choices
# ! without perception of corruption
