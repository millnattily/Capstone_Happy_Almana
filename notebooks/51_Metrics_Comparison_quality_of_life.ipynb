# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files_2_read = ["../data/Metrics_Summary_model_07.txt",
                "../data/Metrics_Summary_model_10.txt",
                "../data/Metrics_Summary_model_11.txt",
                "../data/Metrics_Summary_model_12.txt",
                "../data/Metrics_Summary_model_13.txt",
                "../data/Metrics_Summary_model_14.txt",
                "../data/Metrics_Summary_model_15.txt",
                ]

# %%
df = pd.concat((pd.read_csv(f) for f in files_2_read))
df
# Out:
#                                  model_name  train_rmse  train_r2  train_mae
# 0                        model_07_lin_reg_2       0.499     0.807      0.384  \
# 1                        model_07_lin_reg_3       0.466     0.832      0.357
# 2                        model_07_lin_reg_1       0.544     0.770      0.417
# 3                         model_07_knn_1_25       0.468     0.830      0.362
# 4                         model_07_knn_1_30       0.476     0.825      0.368
# ..                                      ...         ...       ...        ...
# 17  model_15_forest_tree_depth4_max_leaf_20       0.375     0.846      0.282
# 18  model_15_forest_tree_depth4_max_leaf_15       0.376     0.845      0.283
# 19  model_15_forest_tree_depth5_max_leaf_20       0.333     0.879      0.250
# 20                       model_15_ada_boost       0.351     0.868      0.295
# 21                       model_15_gbr_boost       0.118     0.985        NaN
#
#     train_mape  test_rmse  test_r2  test_mae  test_mape  delta_RMSE
# 0        0.077      0.492    0.817     0.376      0.075       0.007  \
# 1        0.071      0.496    0.814     0.376      0.075       0.030
# 2        0.084      0.533    0.785     0.407      0.083       0.011
# 3        0.074      0.497    0.813     0.377      0.078       0.029
# 4        0.075      0.499    0.811     0.378      0.078       0.023
# ..         ...        ...      ...       ...        ...         ...
# 17       0.050      0.480    0.778     0.361      0.070       0.105
# 18       0.050      0.481    0.777     0.362      0.070       0.105
# 19       0.044      0.443    0.810     0.334      0.064       0.110
# 20       0.051      0.443    0.820     0.349      0.065       0.092
# 21         NaN      0.354    0.879       NaN        NaN       0.236
#
#     delta_MAE  delta_R2  mean_node_num  mean_depth  num_of_trees
# 0       0.008     0.010            NaN         NaN           NaN
# 1       0.019     0.018            NaN         NaN           NaN
# 2       0.010     0.015            NaN         NaN           NaN
# 3       0.015     0.017            NaN         NaN           NaN
# 4       0.010     0.014            NaN         NaN           NaN
# ..        ...       ...            ...         ...           ...
# 17      0.079     0.068           30.0         4.0         100.0
# 18      0.079     0.068           28.0         4.0         100.0
# 19      0.084     0.069           39.0         5.0         100.0
# 20      0.054     0.048            NaN         NaN           NaN
# 21        NaN     0.106            NaN         NaN           NaN
#
# [161 rows x 15 columns]

# %%
g=sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# KNN Models

# %%
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'test_r2',
              color = 'darkorange',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'test_mae',
              color = 'green',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'train_r2',
              color = 'darkorange',
              markers= '',
              linestyles='--')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'train_mae',
              color = 'green',
              markers= '',
              linestyles='--')
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,

# %% [markdown]
# due to the much smaller number of observations, we lose balance between train/test performance (model 10 vs. model 7)
# Metrics for prediction are better, but more overfitting!!

# %% [markdown]
# Decision Tree Models

# %%
g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
              x= 'model_name',
              y = 'test_r2',
              color = 'darkorange',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
              x= 'model_name',
              y = 'test_mae',
              color = 'green',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
              x= 'model_name',
              y = 'train_r2',
              color = 'darkorange',
              markers= '',
              linestyles='--')
g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
              x= 'model_name',
              y = 'train_mae',
              color = 'green',
              markers= '',
              linestyles='--')
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,

# %% [markdown]
# R2 performs better than MAE.
# less overfitting for R2, but no good balance for MAE

# %% [markdown]
# Random Forest Models

# %%
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'test_r2',
              color = 'darkorange',
              markers= 'o',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'test_mae',
              color = 'green',
              markers= 'o',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'train_r2',
              color = 'darkorange',
              markers= '*',
              linestyles='--')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'train_mae',
              color = 'green',
              markers= '*',
              linestyles='--')
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# to much overfitting with the new data

# %% [markdown]
# MAPE Minimum as

# %%
df[df['test_mape']==df['test_mape'].min()]
# Out:
#          model_name  train_rmse  train_r2  train_mae  train_mape  test_rmse
# 2  model_14_knn_1_5       0.286     0.911      0.199       0.036      0.407  \
# 2  model_15_knn_1_5       0.290     0.908      0.202       0.037      0.401
#
#    test_r2  test_mae  test_mape  delta_RMSE  delta_MAE  delta_R2
# 2    0.841     0.270      0.054       0.121      0.071     0.070  \
# 2    0.845     0.267      0.054       0.111      0.065     0.063
#
#    mean_node_num  mean_depth  num_of_trees
# 2            NaN         NaN           NaN
# 2            NaN         NaN           NaN
