# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
files_2_read = ["Metrics_Summary_basemodel.txt",
                "Metrics_Summary_model_06.txt",
                "Metrics_Summary_model_07.txt",
                "Metrics_Summary_model_20.txt",
                "Metrics_Summary_model_23.txt",
                "Metrics_Summary_model_24.txt",
                ]

# %%
df = pd.concat((pd.read_csv(f) for f in files_2_read))
df
# Out:
#                              model_name  train_rmse  train_r2  train_mae
# 0                   basemodel_lin_reg_5       0.671     0.642      0.529  \
# 1                   basemodel_lin_reg_8       0.662     0.651      0.519
# 2                   basemodel_lin_reg_7       0.663     0.650      0.523
# 3                    basemodel_knn_1_25       0.634     0.680      0.497
# 4                    basemodel_knn_2_25       0.634     0.680      0.497
# ..                                  ...         ...       ...        ...
# 24   model_24_extra_depth6_max_nodes_54         NaN     0.839      0.355
# 25   model_24_extra_depth7_max_nodes_54         NaN     0.852      0.340
# 26  model_24_extra_depth10_max_nodes_54         NaN     0.860      0.333
# 27   model_24_extra_depth8_max_nodes_54         NaN     0.857      0.335
# 28  model_24_extra_depth12_max_nodes_54         NaN     0.860      0.333
#
#     train_mape  test_rmse  test_r2  test_mae  test_mape  delta_RMSE
# 0        0.104      0.676    0.638     0.530      0.104       0.005  \
# 1        0.103      0.669    0.645     0.520      0.102       0.007
# 2        0.103      0.671    0.643     0.521      0.102       0.008
# 3        0.098      0.634    0.681     0.506      0.099       0.000
# 4        0.098      0.634    0.681     0.506      0.099       0.000
# ..         ...        ...      ...       ...        ...         ...
# 24       0.071        NaN    0.818     0.368      0.074         NaN
# 25       0.068        NaN    0.823     0.363      0.073         NaN
# 26       0.067        NaN    0.829     0.358      0.072         NaN
# 27       0.067        NaN    0.826     0.360      0.073         NaN
# 28       0.067        NaN    0.828     0.359      0.072         NaN
#
#     delta_MAE  delta_R2  mean_node_num  mean_depth  num_of_trees
# 0       0.001     0.004            NaN         NaN           NaN
# 1       0.001     0.006            NaN         NaN           NaN
# 2       0.002     0.007            NaN         NaN           NaN
# 3       0.009     0.001            NaN         NaN           NaN
# 4       0.009     0.001            NaN         NaN           NaN
# ..        ...       ...            ...         ...           ...
# 24      0.013     0.021            NaN         NaN           NaN
# 25      0.023     0.029            NaN         NaN           NaN
# 26      0.025     0.031            NaN         NaN           NaN
# 27      0.025     0.031            NaN         NaN           NaN
# 28      0.026     0.032            NaN         NaN           NaN
#
# [142 rows x 15 columns]

# %%
g=sns.set_theme(rc={'figure.figsize':(11.7,8.27)})

# %% [markdown]
# KNN Models

# %%
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'test_r2',
              color = 'darkorange',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'test_mae',
              color = 'green',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'train_r2',
              color = 'darkorange',
              markers= '',
              linestyles='--')
g=sns.pointplot(data = df.query('model_name.str.contains("knn")'),
              x= 'model_name',
              y = 'train_mae',
              color = 'green',
              markers= '',
              linestyles='--')
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,

# %% [markdown]
# Decision Tree Models

# %%
g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
              x= 'model_name',
              y = 'test_r2',
              color = 'darkorange',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
              x= 'model_name',
              y = 'test_mae',
              color = 'green',
              markers= '',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
              x= 'model_name',
              y = 'train_r2',
              color = 'darkorange',
              markers= '',
              linestyles='--')
g=sns.pointplot(data = df.query('model_name.str.contains("dectree")'),
              x= 'model_name',
              y = 'train_mae',
              color = 'green',
              markers= '',
              linestyles='--')
g.set_xticklabels(g.get_xticklabels(), rotation=90);
# Out:
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0), (1.0, 0.5490196078431373, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,
# /Users/maritaschmidt/NEUE_FISCHE/Capstone_Happy_Almana/.venv/lib/python3.11/site-packages/seaborn/categorical.py:1680: UserWarning: You passed a edgecolor/edgecolors ([(0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0), (0.0, 0.5019607843137255, 0.0)]) for an unfilled marker ('').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y,

# %% [markdown]
# Random Forest Models

# %%
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'test_r2',
              color = 'darkorange',
              markers= 'o',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'test_mae',
              color = 'green',
              markers= 'o',
              linestyles='-')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'train_r2',
              color = 'darkorange',
              markers= '*',
              linestyles='--')
g=sns.pointplot(data = df.query('model_name.str.contains("forest")'),
              x= 'model_name',
              y = 'train_mae',
              color = 'green',
              markers= '*',
              linestyles='--')
g.set_xticklabels(g.get_xticklabels(), rotation=90);

# %% [markdown]
# MAPE - Mean absolute percentage error

# %% [markdown]
# What is a good mean absolute percentage error? A MAPE less than 5% is considered as an indication that the forecast is acceptably accurate. A MAPE greater than 10% but less than 25% indicates low, but acceptable accuracy and MAPE greater than 25% very low accuracy.

# %%
df[df['test_mape']==df['test_mape'].min()]
# Out:
#           model_name  train_rmse  train_r2  train_mae  train_mape  test_rmse
# 0  model_23_knn_1_10         NaN     0.873      0.305       0.062        NaN  \
#
#    test_r2  test_mae  test_mape  delta_RMSE  delta_MAE  delta_R2
# 0    0.866     0.317      0.063         NaN      0.012     0.007  \
#
#    mean_node_num  mean_depth  num_of_trees
# 0            NaN         NaN           NaN

# %% [markdown]
# Welches sind die besten Modelle? (aus meiner Sicht)
#
#
# ### KNN Model: Model 20
#
# manhattan, 15 neighbors
#
# ### Features from Happiness:
# + log_gdp_per_capita
# + social_support
# + healthy_life_expectancy_at_birth
# +
# + perception of corruption
# + positive affect
# + negative affect
#
# ### Features from HDI:
#  + hdi
#
# ---
#
# ### Random Forest: Model 23
#
# ### Features from Happiness:
# + log_gdp_per_capita
# + social_support
# + healthy_life_expectancy_at_birth
# + freedom_to_make_life_choices
# + perception of corruption
# + positive affect
# + negative affect
#
# ### Features from HDI:
#  + hdi
